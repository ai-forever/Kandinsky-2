# %%
# !pip install 'git+https://github.com/ai-forever/Kandinsky-2.git'
# !pip install git+https://github.com/openai/CLIP.git

# %%
from kandinsky2 import get_kandinsky2

# %%
model = get_kandinsky2('cuda', task_type='text2img', cache_dir='/tmp/kandinsky2', use_auth_token='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', model_version='2.1', use_flash_attention=False)
# Out:
# making attention of type 'vanilla' with 512 in_channels
# making attention of type 'vanilla' with 512 in_channels
# making attention of type 'vanilla' with 512 in_channels
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.

# %%
images = model.generate_text2img('''red cat, 4k photo''', num_steps=100,
                          batch_size=1, guidance_scale=4,
                           h=768, w=768
                           ,sampler='p_sampler', prior_cf_scale=4,
                            prior_steps="5",)

# %%
images[0]
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7FE43C97B760>
